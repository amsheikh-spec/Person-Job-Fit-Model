# %%
import pandas as pd

df = pd.read_csv("preprocessed_resume.csv")

resume_count = len(df)
print(resume_count)
# Out:
# 24432

# %%
df.head(5)
# Out:
#                                               resume                   label
# 0  database administrator database administrator ...  database administrator
# 1  database administrator database administrator ...  database administrator
# 2  oracle database administrator oracle database ...  database administrator
# 3  amazon redshift administrator etl developer bu...  database administrator
# 4  scrum master scrum master scrum master richmon...  database administrator

# %%
duplicate_count = df.duplicated('resume').sum()
print("Duplicate records :", duplicate_count)
# Out:
# Duplicate records : 766

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 23666

# %%
# !pip install skillNer
# !python -m spacy download en_core_web_lg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.0 MB/s eta 0:00:00
# ...
#   Created wheel for skillNer: filename=skillNer-1.0.3-py3-none-any.whl size=25626 sha256=bdd393cac256020a5a85c88ac8960358f0a202b6a81216894e4a9d4f2ff7b9af
#   Stored in directory: /root/.cache/pip/wheels/9a/f1/7a/3201e01141cdb862654585eb16412785ed9973459639c351e4
# Successfully built skillNer
# ...
# 2023-07-18 22:14:45.944771: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-18 22:14:46.961092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# imports
import spacy
from spacy.matcher import PhraseMatcher

# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor

# init params of skill extractor
nlp = spacy.load("en_core_web_lg")
# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
def extract_skills(resume):
  annotations = skill_extractor.annotate(resume, 0.8)
  skills_list = annotations['results']['full_matches']

  skills = []
  for sk in skills_list:
    skills.append(sk['doc_node_value'])

  skills_list = annotations['results']['ngram_scored']
  for sk in skills_list:
    skills.append(sk['doc_node_value'])
  return list(set(skills))

# %%
df = df[:20]
df
# Out:
#                                                resume                   label
# 0   database administrator database administrator ...  database administrator
# 1   database administrator database administrator ...  database administrator
# 2   oracle database administrator oracle database ...  database administrator
# 3   amazon redshift administrator etl developer bu...  database administrator
# 4   scrum master scrum master scrum master richmon...  database administrator
# 5   oracle database administrator oracle database ...  database administrator
# 6   oracle database administrator oracle database ...  database administrator
# 7   lead database administratordeveloper lead data...  database administrator
# 8   database administrator database developer data...  database administrator
# 9   oracle database administrator oracle database ...  database administrator
# 10  database administrator database administrator ...  database administrator
# ...

# %%
df['skills'] = df['resume'].apply(extract_skills)
# Out:
# /usr/local/lib/python3.10/dist-packages/skillNer/utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
# <ipython-input-13-6b73e8e0519b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['skills'] = df['resume'].apply(extract_skills)

# %%
df.head(2)
# Out:
#                                               resume                   label  \
# 0  database administrator database administrator ...  database administrator
# 1  database administrator database administrator ...  database administrator
#
#                                               skills
# 0  [native sql, project scope, index, recovery te...
# 1  [management systems, microprocessors, microsof...

# %%
df.to_csv("preprocessed_resume_1.csv")
